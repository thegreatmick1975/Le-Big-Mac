# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

import os


data=pd.read_csv('menu.csv')

# %%
data.pivot_table('Protein','Category').plot(kind='bar',stacked=True,color='r')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
data.pivot_table('Total Fat', 'Category').plot(kind='bar',stacked=True,color='b')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
data.pivot_table('Cholesterol','Category').plot(kind='bar',stacked=True,color='g')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
f,ax=plt.subplots(figsize=(18,11))
sns.heatmap(data.corr(),annot=True,linewidths=5,fmt='.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
data.Calories.plot(kind='hist',bins=40,figsize=(18,11))
plt.xlabel('Calories')
plt.ylabel('Sugars')
# Out:
# Text(0, 0.5, 'Sugars')

# %%
data.plot(kind='scatter',x='Cholesterol',y='Sugars',alpha=0.4,color='m')
plt.xlabel('Cholesterol')
plt.ylabel('Sugars')
plt.title('Why do we poison children with this shit?')
# Out:
# Text(0.5, 1.0, 'Why do we poison children with this shit?')

# %%
dataFrame=data[['Calories']]
print(type(dataFrame))
print('')
series=data['Calories']
print(type(series))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# <class 'pandas.core.series.Series'>

# %%
x=data['Total Fat'] >30
data[x]
# Out:
#                Category                                               Item  \
# 11            Breakfast                    Sausage Biscuit (Large Biscuit)
# 12            Breakfast         Sausage Biscuit with Egg (Regular Biscuit)
# 13            Breakfast           Sausage Biscuit with Egg (Large Biscuit)
# 15            Breakfast    Sausage Biscuit with Egg Whites (Large Biscuit)
# 18            Breakfast              Steak & Egg Biscuit (Regular Biscuit)
# 22            Breakfast                   Sausage, Egg & Cheese McGriddles
# 24            Breakfast                          Bacon, Egg & Cheese Bagel
# 26            Breakfast                          Steak, Egg & Cheese Bagel
# 27            Breakfast                    Big Breakfast (Regular Biscuit)
# 28            Breakfast                      Big Breakfast (Large Biscuit)
# 29            Breakfast    Big Breakfast with Egg Whites (Regular Biscuit)
# 30            Breakfast      Big Breakfast with Egg Whites (Large Biscuit)
# 31            Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32            Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 33            Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34            Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 45          Beef & Pork          Quarter Pounder with Bacon Habanero Ranch
# 47          Beef & Pork                 Double Quarter Pounder with Cheese
# 51          Beef & Pork                             Bacon Clubhouse Burger
# 59       Chicken & Fish               Premium Crispy Chicken Club Sandwich
# 63       Chicken & Fish            Bacon Clubhouse Crispy Chicken Sandwich
# 70       Chicken & Fish    Premium McWrap Chicken & Bacon (Crispy Chicken)
# 72       Chicken & Fish    Premium McWrap Chicken & Ranch (Crispy Chicken)
# 74       Chicken & Fish  Premium McWrap Southwest Chicken (Crispy Chicken)
# 81       Chicken & Fish                       Chicken McNuggets (20 piece)
# 82       Chicken & Fish                       Chicken McNuggets (40 piece)
# 231        Coffee & Tea                      Frappé Chocolate Chip (Large)
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 11    4.6 oz (131 g)       480                280       31.0
# 12    5.7 oz (163 g)       510                290       33.0
# 13    6.2 oz (177 g)       570                330       37.0
# 15    6.4 oz (181 g)       520                280       32.0
# 18    7.1 oz (201 g)       540                290       32.0
# 22    7.1 oz (201 g)       550                280       31.0
# 24    6.9 oz (197 g)       620                280       31.0
# 26    8.5 oz (241 g)       670                310       35.0
# 27    9.5 oz (269 g)       740                430       48.0
# 28     10 oz (283 g)       800                470       52.0
# 29    9.6 oz (272 g)       640                330       37.0
# 30   10.1 oz (286 g)       690                370       41.0
# 31   14.8 oz (420 g)      1090                510       56.0
# 32   15.3 oz (434 g)      1150                540       60.0
# 33   14.9 oz (423 g)       990                410       46.0
# 34   15.4 oz (437 g)      1050                450       50.0
# 45    8.3 oz (235 g)       610                280       31.0
# 47     10 oz (283 g)       750                380       43.0
# 51    9.5 oz (270 g)       720                360       40.0
# 59    8.8 oz (249 g)       670                300       33.0
# 63     10 oz (284 g)       750                340       38.0
# 70   11.1 oz (316 g)       630                280       32.0
# 72   10.9 oz (310 g)       610                280       31.0
# 74   11.1 oz (314 g)       670                300       33.0
# 81   11.4 oz (323 g)       940                530       59.0
# 82   22.8 oz (646 g)      1880               1060      118.0
# 231     22 fl oz cup       760                280       31.0
# 253  16.2 oz (460 g)       930                290       33.0
# 258  14.2 oz (403 g)       810                290       32.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 11                          48           13.0                             65
# 12                          50           14.0                             71
# 13                          57           15.0                             74
# 15                          49           13.0                             65
# 18                          49           16.0                             78
# 22                          48           12.0                             61
# 24                          48           11.0                             56
# 26                          53           13.0                             63
# 27                          73           17.0                             87
# 28                          80           18.0                             90
# 29                          57           14.0                             69
# 30                          63           14.0                             72
# 31                          87           19.0                             96
# 32                          93           20.0                            100
# 33                          70           16.0                             78
# 34                          77           16.0                             81
# 45                          48           13.0                             64
# 47                          66           19.0                             96
# 51                          62           15.0                             75
# 59                          51            9.0                             44
# 63                          59           10.0                             51
# 70                          49            9.0                             45
# 72                          47            8.0                             40
# 74                          51            8.0                             40
# 81                          91           10.0                             50
# 82                         182           20.0                            101
# 231                         48           20.0                            101
# 253                         50           20.0                            102
# 258                         50           15.0                             76
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 11         0.0  ...             39                             13
# 12         0.0  ...             36                             12
# 13         0.0  ...             42                             14
# 15         0.0  ...             40                             13
# 18         1.0  ...             38                             13
# 22         0.0  ...             48                             16
# 24         0.5  ...             57                             19
# 26         1.5  ...             56                             19
# 27         0.0  ...             51                             17
# 28         0.0  ...             56                             19
# 29         0.0  ...             50                             17
# 30         0.0  ...             55                             18
# 31         0.0  ...            111                             37
# 32         0.0  ...            116                             39
# 33         0.0  ...            110                             37
# 34         0.0  ...            115                             38
# 45         1.5  ...             46                             15
# 47         2.5  ...             42                             14
# 51         1.5  ...             51                             17
# 59         0.0  ...             58                             19
# 63         0.5  ...             65                             22
# 70         0.5  ...             56                             19
# 72         0.5  ...             56                             19
# 74         0.5  ...             68                             23
# 81         0.0  ...             59                             20
# 82         1.0  ...            118                             39
# 231        1.5  ...            111                             37
# 253        1.0  ...            139                             46
# 258        1.0  ...            114                             38
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 11               3                             11       3       11
# 12               2                              6       2       18
# 13               3                             11       3       18
# 15               3                             11       3       18
# 18               2                              8       3       25
# 22               2                              9      15       20
# 24               3                             11       7       30
# 26               3                             12       7       33
# 27               3                             12       3       28
# 28               4                             17       3       28
# 29               3                             12       3       26
# 30               4                             17       4       26
# 31               6                             23      17       36
# 32               7                             28      17       36
# 33               6                             23      17       35
# 34               7                             28      18       35
# 45               3                             14      10       37
# 47               3                             11      10       48
# 51               4                             14      14       39
# 59               3                             14      11       36
# 63               4                             15      16       36
# 70               3                             13       7       32
# 72               3                             14       8       27
# 74               5                             19      12       27
# 81               3                             12       0       44
# 82               6                             24       1       87
# 231              1                              5      99       12
# 253              2                              7     128       20
# 258              2                              9     103       21
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 11                           4                          0
# 12                           6                          0
# 13                          10                          0
# 15                           4                          0
# 18                          10                          2
# 22                          10                          0
# 24                          20                         15
# 26                          20                          4
# 27                          15                          2
# 28                          15                          2
# 29                           0                          2
# 30                           4                          2
# 31                          15                          2
# 32                          15                          2
# 33                           0                          2
# 34                           4                          2
# 45                           8                         20
# 47                          10                          2
# 51                           8                         25
# 59                           8                         20
# 63                           8                         25
# 70                          60                         20
# 72                          60                         15
# 74                          60                         15
# 81                           0                          8
# 82                           0                         15
# 231                         20                          0
# 253                         25                          0
# 258                         20                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 11                         8                    15
# 12                        10                    20
# 13                        10                    20
# 15                         8                    15
# 18                        20                    25
# 22                        20                    15
# 24                        20                    20
# 26                        25                    25
# 27                        15                    25
# 28                        15                    30
# 29                        10                    15
# 30                        10                    15
# 31                        25                    40
# 32                        30                    40
# 33                        25                    30
# 34                        25                    30
# 45                        25                    30
# 47                        30                    35
# 51                        30                    25
# 59                        30                    20
# 63                        30                    15
# 70                        20                    20
# 72                        20                    20
# 74                        20                    20
# 81                         4                    10
# 82                         8                    25
# 231                       35                     6
# 253                       70                    10
# 258                       60                     6
#
# [29 rows x 24 columns]

# %%
data[(data['Calories']>300) & (data['Total Fat']>15)]
# Out:
#                Category                                               Item  \
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 5             Breakfast                               Steak & Egg McMuffin
# 6             Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# ..                  ...                                                ...
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# 5     6.5 oz (185 g)       430                210       23.0
# 6     5.3 oz (150 g)       460                230       26.0
# ..               ...       ...                ...        ...
# 253  16.2 oz (460 g)       930                290       33.0
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 2                           35            8.0                             42
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# 5                           36            9.0                             46
# 6                           40           13.0                             65
# ..                         ...            ...                            ...
# 253                         50           20.0                            102
# 255                         26            9.0                             44
# 256                         35           12.0                             58
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 2          0.0  ...             29                             10
# 3          0.0  ...             30                             10
# 4          0.0  ...             30                             10
# 5          1.0  ...             31                             10
# 6          0.0  ...             38                             13
# ..         ...  ...            ...                            ...
# 253        1.0  ...            139                             46
# 255        0.5  ...             80                             27
# 256        1.0  ...            106                             35
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 2                4                             17       2       14
# 3                4                             17       2       21
# 4                4                             17       2       21
# 5                4                             18       3       26
# 6                2                              7       3       19
# ..             ...                            ...     ...      ...
# 253              2                              7     128       20
# 255              1                              4      64       12
# 256              1                              5      85       15
# 258              2                              9     103       21
# 259              1                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 2                            8                          0
# 3                           15                          0
# 4                            6                          0
# 5                           15                          2
# 6                           10                          8
# ..                         ...                        ...
# 253                         25                          0
# 255                         15                          0
# 256                         20                          0
# 258                         20                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 2                         25                    10
# 3                         30                    15
# 4                         25                    10
# 5                         30                    20
# 6                         15                    15
# ..                       ...                   ...
# 253                       70                    10
# 255                       40                     8
# 256                       50                    10
# 258                       60                     6
# 259                       30                     4
#
# [105 rows x 24 columns]

# %%
threshold=sum(data['Calories'])/len(data['Calories'])
print('threshold is', threshold)

data["cal_level"]=["high" if i>threshold else "low" for i in data['Calories']]
data.loc[:15,["cal_level","Calories","Item"]]
# Out:
# threshold is 368.2692307692308
#    cal_level  Calories                                               Item
# 0        low       300                                       Egg McMuffin
# 1        low       250                                  Egg White Delight
# 2       high       370                                   Sausage McMuffin
# 3       high       450                          Sausage McMuffin with Egg
# 4       high       400                   Sausage McMuffin with Egg Whites
# 5       high       430                               Steak & Egg McMuffin
# 6       high       460      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7       high       520        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8       high       410  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9       high       470  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 10      high       430                  Sausage Biscuit (Regular Biscuit)
# 11      high       480                    Sausage Biscuit (Large Biscuit)
# 12      high       510         Sausage Biscuit with Egg (Regular Biscuit)
# 13      high       570           Sausage Biscuit with Egg (Large Biscuit)
# 14      high       460  Sausage Biscuit with Egg Whites (Regular Biscuit)
# 15      high       520    Sausage Biscuit with Egg Whites (Large Biscuit)

# %%
data['Calories'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['Trans Fat'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
data['Cholesterol'].value_counts().sort_index().plot.area()
# Out:
# <AxesSubplot:>

# %%
data.plot.scatter(x='Calories',y='Carbohydrates')
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='Carbohydrates'>

# %%
data.plot.scatter(x='Carbohydrates (% Daily Value)',y='Carbohydrates')
# Out:
# <AxesSubplot:xlabel='Carbohydrates (% Daily Value)', ylabel='Carbohydrates'>

# %%
data.plot.scatter(x='Sodium (% Daily Value)',y='Total Fat')
# Out:
# <AxesSubplot:xlabel='Sodium (% Daily Value)', ylabel='Total Fat'>

# %%
data.plot.scatter(x='Cholesterol',y='Total Fat')
# Out:
# <AxesSubplot:xlabel='Cholesterol', ylabel='Total Fat'>

# %%
print(data['Item'].value_counts(dropna=False))
# Out:
# Egg McMuffin                                        1
# Nonfat Latte (Small)                                1
# Nonfat Latte (Large)                                1
# Nonfat Caramel Latte (Small)                        1
# Nonfat Caramel Latte (Medium)                       1
#                                                    ..
# Chipotle BBQ Snack Wrap (Grilled Chicken)           1
# Honey Mustard Snack Wrap (Crispy Chicken)           1
# Honey Mustard Snack Wrap (Grilled Chicken)          1
# Ranch Snack Wrap (Crispy Chicken)                   1
# McFlurry with Reese's Peanut Butter Cups (Snack)    1
# Name: Item, Length: 260, dtype: int64

# %%
data.boxplot(column='Calories', by='Calcium (% Daily Value)')
# Out:
# <AxesSubplot:title={'center':'Calories'}, xlabel='Calcium (% Daily Value)'>

# %%
data_new=data.head()
data_new
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  \
# 0                             25        0.0  ...
# 1                             15        0.0  ...
# 2                             42        0.0  ...
# 3                             52        0.0  ...
# 4                             42        0.0  ...
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
# 2                             10              4
# 3                             10              4
# 4                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)  \
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
#    cal_level
# 0        low
# 1        low
# 2       high
# 3       high
# 4       high
#
# [5 rows x 25 columns]

# %%
melted_data=pd.melt(frame=data_new,id_vars = 'Item',value_vars=['Calories','Protein'])
melted_data
# Out:
#                                Item  variable  value
# 0                      Egg McMuffin  Calories    300
# 1                 Egg White Delight  Calories    250
# 2                  Sausage McMuffin  Calories    370
# 3         Sausage McMuffin with Egg  Calories    450
# 4  Sausage McMuffin with Egg Whites  Calories    400
# 5                      Egg McMuffin   Protein     17
# 6                 Egg White Delight   Protein     18
# 7                  Sausage McMuffin   Protein     14
# 8         Sausage McMuffin with Egg   Protein     21
# 9  Sausage McMuffin with Egg Whites   Protein     21

# %%
melted_data.pivot(index='Item',columns='variable',values='value')
# Out:
# variable                          Calories  Protein
# Item
# Egg McMuffin                           300       17
# Egg White Delight                      250       18
# Sausage McMuffin                       370       14
# Sausage McMuffin with Egg              450       21
# Sausage McMuffin with Egg Whites       400       21

# %%
data3=data['Calories'].head()
data4=data['Calories from Fat'].head()
conc_data_col=pd.concat([data3,data4],axis=1)
conc_data_col
# Out:
#    Calories  Calories from Fat
# 0       300                120
# 1       250                 70
# 2       370                200
# 3       450                250
# 4       400                210

# %%
data['Cholesterol']=data['Cholesterol'].astype('float64')
data['Serving Size']=data['Serving Size'].astype('category')

# %%
data5=data.loc[:,["Calcium (% Daily Value)","Vitamin A (% Daily Value)","Vitamin C (% Daily Value)"]]
data5.plot()
# Out:
# <AxesSubplot:>

# %%
data5.plot(subplots=True)
plt.show()

# %%
data.plot(kind="scatter",x="Calories",y="Vitamin C (% Daily Value)")
plt.show()
